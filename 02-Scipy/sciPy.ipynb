# %% [markdown]
# # Intro to sciPy

# %% [markdown]
# #### The following python code performs curve fitting on semirandom data

# %% [markdown]
# import *libraries*

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plot

# %% [markdown]
# define test funtion

# %%
def test_func(x,a,b):
    return a * np.cos(b * x)

# %% [markdown]
# seed the random number generator

# %%
np.random.seed(0)

# %% [markdown]
# generate points

# %%
x_data = np.linspace(-5, 5, num=50)
y_data = 140 * np.sin(1.5 * x_data)
#the data on the y_axis changes as the values(140 changes)

# %%
params, covariance = optimize.curve_fit( test_func, x_data, y_data, p0=[2,2])

# %% [markdown]
# we plot the values

# %%
plot.figure(figsize=[6,4])
plot.scatter(x_data,y_data,label='Data')
plot.plot(x_data, test_func(x_data, params[0], params[1]), label='Fitted function')

plot.legend(loc='best')
plot.show()

# %% [markdown]
# ####  The following python code performs interpolation for missing data

# %%
from scipy.interpolate import interp1d

# %%
np.random.seed(0)

# %% [markdown]
# generate sparse data

# %%
measured_time = np.linspace(0,1,10)
noise = 1e-1 * (np.random.random(10) * 2 - 1)
measures = np.sin(2 * np.pi * measured_time) + noise

# %% [markdown]
# interpolate to provide new time points

# %%
interpolation_time = np.linspace(0,1,50)

# %%
linear_interp = interp1d(measured_time, measures)
linear_results = linear_interp(interpolation_time)

# %%
cubic_interp = interp1d(measured_time, measures, kind='cubic')

# %%
cubic_results = cubic_interp(interpolation_time)

# %% [markdown]
# plot the data and the interpolation

# %%
plot.figure(figsize=[6,4])
plot.plot(measured_time, measures, 'o', ms=6, label='measures')
plot.plot(interpolation_time,linear_results, label='linear interpolation')
plot.plot(interpolation_time,cubic_results, label='cubic interpolation')
plot.legend()
plot.show()
